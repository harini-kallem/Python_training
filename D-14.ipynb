# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0    1.0    0.0   7.2500        S  Third
# 1           1       1  female  38.0    1.0    0.0  71.2833        C  First
# 2           1       3  female  26.0    0.0    0.0   7.9250        S  Third
# 3           1       1  female  35.0    1.0    0.0  53.1000        S  First
# 4           0       3    male  35.0    0.0    0.0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 365         0       3    male  30.0    0.0    0.0   7.2500        S  Third
# 366         1       1  female  60.0    1.0    0.0  75.2500        C  First
# 367         1       3  female   NaN    0.0    0.0   7.2292        C  Third
# 368         1       3  female   NaN    0.0    0.0   7.7500        Q  Third
# 369         1       1   femal   NaN    NaN    NaN      NaN      NaN    NaN
#
#        who adult_male deck  embark_town alive  alone
# 0      man       True  NaN  Southampton    no  False
# 1    woman      False    C    Cherbourg   yes  False
# 2    woman      False  NaN  Southampton   yes   True
# 3    woman      False    C  Southampton   yes  False
# 4      man       True  NaN  Southampton    no   True
# ..     ...        ...  ...          ...   ...    ...
# 365    man       True  NaN  Southampton    no   True
# 366  woman      False    D    Cherbourg   yes  False
# 367  woman      False  NaN    Cherbourg   yes   True
# 368  woman      False  NaN   Queenstown   yes   True
# 369    NaN        NaN  NaN          NaN   NaN    NaN
#
# [370 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     370 non-null    int64
#  1   pclass       370 non-null    int64
#  2   sex          370 non-null    object
#  3   age          294 non-null    float64
#  4   sibsp        369 non-null    float64
#  5   parch        369 non-null    float64
#  6   fare         369 non-null    float64
#  7   embarked     368 non-null    object
#  8   class        369 non-null    category
#  9   who          369 non-null    object
#  10  adult_male   369 non-null    object
#  11  deck         84 non-null     category
#  12  embark_town  368 non-null    object
#  13  alive        369 non-null    object
#  14  alone        369 non-null    object
# dtypes: category(2), float64(4), int64(2), object(7)
# memory usage: 38.9+ KB

# %%
df.sample()
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class  who  \
# 262         0       1  male  52.0    1.0    1.0  79.65        S  First  man
#
#     adult_male deck  embark_town alive  alone
# 262       True    E  Southampton    no  False

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0    1.0    0.0   7.2500        S  Third
# 1         1       1  female  38.0    1.0    0.0  71.2833        C  First
# 2         1       3  female  26.0    0.0    0.0   7.9250        S  Third
# 3         1       1  female  35.0    1.0    0.0  53.1000        S  First
# 4         0       3    male  35.0    0.0    0.0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 365         0       3    male  30.0    0.0    0.0   7.2500        S  Third
# 366         1       1  female  60.0    1.0    0.0  75.2500        C  First
# 367         1       3  female   NaN    0.0    0.0   7.2292        C  Third
# 368         1       3  female   NaN    0.0    0.0   7.7500        Q  Third
# 369         1       1   femal   NaN    NaN    NaN      NaN      NaN    NaN
#
#        who adult_male deck  embark_town alive  alone
# 365    man       True  NaN  Southampton    no   True
# 366  woman      False    D    Cherbourg   yes  False
# 367  woman      False  NaN    Cherbourg   yes   True
# 368  woman      False  NaN   Queenstown   yes   True
# 369    NaN        NaN  NaN          NaN   NaN    NaN

# %%
df['alive'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['who'].value_counts()
# Out:
# who
# man      210
# woman    123
# child     36
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 365    False
# 366    False
# 367    False
# 368     True
# 369    False
# Length: 370, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 31

# %%
df[df.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN    0.0    0.0   7.7500        Q   Third
# 76          0       3    male   NaN    0.0    0.0   7.8958        S   Third
# 77          0       3    male   NaN    0.0    0.0   8.0500        S   Third
# 87          0       3    male   NaN    0.0    0.0   8.0500        S   Third
# 95          0       3    male   NaN    0.0    0.0   8.0500        S   Third
# 101         0       3    male   NaN    0.0    0.0   7.8958        S   Third
# 121         0       3    male   NaN    0.0    0.0   8.0500        S   Third
# 133         1       2  female  29.0    1.0    0.0  26.0000        S  Second
# 173         0       3    male  21.0    0.0    0.0   7.9250        S   Third
# 196         0       3    male   NaN    0.0    0.0   7.7500        Q   Third
# 198         1       3  female   NaN    0.0    0.0   7.7500        Q   Third
# 201         0       3    male   NaN    8.0    2.0  69.5500        S   Third
# 213         0       2    male  30.0    0.0    0.0  13.0000        S  Second
# 223         0       3    male   NaN    0.0    0.0   7.8958        S   Third
# 241         1       3  female   NaN    1.0    0.0  15.5000        Q   Third
# 260         0       3    male   NaN    0.0    0.0   7.7500        Q   Third
# 274         1       3  female   NaN    0.0    0.0   7.7500        Q   Third
# 295         0       1    male   NaN    0.0    0.0  27.7208        C   First
# 300         1       3  female   NaN    0.0    0.0   7.7500        Q   Third
# 304         0       3    male   NaN    0.0    0.0   8.0500        S   Third
# 313         0       3    male  28.0    0.0    0.0   7.8958        S   Third
# 320         0       3    male  22.0    0.0    0.0   7.2500        S   Third
# 324         0       3    male   NaN    8.0    2.0  69.5500        S   Third
# 335         0       3    male   NaN    0.0    0.0   7.8958        S   Third
# 343         0       2    male  25.0    0.0    0.0  13.0000        S  Second
# 354         0       3    male   NaN    0.0    0.0   7.2250        C   Third
# 355         0       3    male  28.0    0.0    0.0   9.5000        S   Third
# 358         1       3  female   NaN    0.0    0.0   7.8792        Q   Third
# 359         1       3  female   NaN    0.0    0.0   7.8792        Q   Third
# 364         0       3    male   NaN    1.0    0.0  15.5000        Q   Third
# 368         1       3  female   NaN    0.0    0.0   7.7500        Q   Third
#
#        who adult_male deck  embark_town alive  alone
# 47   woman      False  NaN   Queenstown   yes   True
# 76     man       True  NaN  Southampton    no   True
# 77     man       True  NaN  Southampton    no   True
# 87     man       True  NaN  Southampton    no   True
# 95     man       True  NaN  Southampton    no   True
# 101    man       True  NaN  Southampton    no   True
# 121    man       True  NaN  Southampton    no   True
# 133  woman      False  NaN  Southampton   yes  False
# 173    man       True  NaN  Southampton    no   True
# 196    man       True  NaN   Queenstown    no   True
# 198  woman      False  NaN   Queenstown   yes   True
# 201    man       True  NaN  Southampton    no  False
# 213    man       True  NaN  Southampton    no   True
# 223    man       True  NaN  Southampton    no   True
# 241  woman      False  NaN   Queenstown   yes  False
# 260    man       True  NaN   Queenstown    no   True
# 274  woman      False  NaN   Queenstown   yes   True
# 295    man       True  NaN    Cherbourg    no   True
# 300  woman      False  NaN   Queenstown   yes   True
# 304    man       True  NaN  Southampton    no   True
# 313    man       True  NaN  Southampton    no   True
# 320    man       True  NaN  Southampton    no   True
# 324    man       True  NaN  Southampton    no  False
# 335    man       True  NaN  Southampton    no   True
# 343    man       True  NaN  Southampton    no   True
# 354    man       True  NaN    Cherbourg    no   True
# 355    man       True  NaN  Southampton    no   True
# 358  woman      False  NaN   Queenstown   yes   True
# 359  woman      False  NaN   Queenstown   yes   True
# 364    man       True  NaN   Queenstown    no  False
# 368  woman      False  NaN   Queenstown   yes   True

# %%
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0    1.0    0.0   7.2500        S  Third
# 1           1       1  female  38.0    1.0    0.0  71.2833        C  First
# 2           1       3  female  26.0    0.0    0.0   7.9250        S  Third
# 3           1       1  female  35.0    1.0    0.0  53.1000        S  First
# 4           0       3    male  35.0    0.0    0.0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 363         0       3    male  35.0    0.0    0.0   7.0500        S  Third
# 365         0       3    male  30.0    0.0    0.0   7.2500        S  Third
# 366         1       1  female  60.0    1.0    0.0  75.2500        C  First
# 367         1       3  female   NaN    0.0    0.0   7.2292        C  Third
# 369         1       1   femal   NaN    NaN    NaN      NaN      NaN    NaN
#
#        who adult_male deck  embark_town alive  alone
# 0      man       True  NaN  Southampton    no  False
# 1    woman      False    C    Cherbourg   yes  False
# 2    woman      False  NaN  Southampton   yes   True
# 3    woman      False    C  Southampton   yes  False
# 4      man       True  NaN  Southampton    no   True
# ..     ...        ...  ...          ...   ...    ...
# 363    man       True  NaN  Southampton    no   True
# 365    man       True  NaN  Southampton    no   True
# 366  woman      False    D    Cherbourg   yes  False
# 367  woman      False  NaN    Cherbourg   yes   True
# 369    NaN        NaN  NaN          NaN   NaN    NaN
#
# [339 rows x 15 columns]

# %%
df.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0    1.0    0.0   7.2500        S
# 1        1         1       1  female  38.0    1.0    0.0  71.2833        C
# 2        2         1       3  female  26.0    0.0    0.0   7.9250        S
# 3        3         1       1  female  35.0    1.0    0.0  53.1000        S
# 4        4         0       3    male  35.0    0.0    0.0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 365    365         0       3    male  30.0    0.0    0.0   7.2500        S
# 366    366         1       1  female  60.0    1.0    0.0  75.2500        C
# 367    367         1       3  female   NaN    0.0    0.0   7.2292        C
# 368    368         1       3  female   NaN    0.0    0.0   7.7500        Q
# 369    369         1       1   femal   NaN    NaN    NaN      NaN      NaN
#
#      class    who adult_male deck  embark_town alive  alone
# 0    Third    man       True  NaN  Southampton    no  False
# 1    First  woman      False    C    Cherbourg   yes  False
# 2    Third  woman      False  NaN  Southampton   yes   True
# 3    First  woman      False    C  Southampton   yes  False
# 4    Third    man       True  NaN  Southampton    no   True
# ..     ...    ...        ...  ...          ...   ...    ...
# 365  Third    man       True  NaN  Southampton    no   True
# 366  First  woman      False    D    Cherbourg   yes  False
# 367  Third  woman      False  NaN    Cherbourg   yes   True
# 368  Third  woman      False  NaN   Queenstown   yes   True
# 369    NaN    NaN        NaN  NaN          NaN   NaN    NaN
#
# [370 rows x 16 columns]

# %%
df.reset_index(drop=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0    1.0    0.0   7.2500        S  Third
# 1           1       1  female  38.0    1.0    0.0  71.2833        C  First
# 2           1       3  female  26.0    0.0    0.0   7.9250        S  Third
# 3           1       1  female  35.0    1.0    0.0  53.1000        S  First
# 4           0       3    male  35.0    0.0    0.0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 365         0       3    male  30.0    0.0    0.0   7.2500        S  Third
# 366         1       1  female  60.0    1.0    0.0  75.2500        C  First
# 367         1       3  female   NaN    0.0    0.0   7.2292        C  Third
# 368         1       3  female   NaN    0.0    0.0   7.7500        Q  Third
# 369         1       1   femal   NaN    NaN    NaN      NaN      NaN    NaN
#
#        who adult_male deck  embark_town alive  alone
# 0      man       True  NaN  Southampton    no  False
# 1    woman      False    C    Cherbourg   yes  False
# 2    woman      False  NaN  Southampton   yes   True
# 3    woman      False    C  Southampton   yes  False
# 4      man       True  NaN  Southampton    no   True
# ..     ...        ...  ...          ...   ...    ...
# 365    man       True  NaN  Southampton    no   True
# 366  woman      False    D    Cherbourg   yes  False
# 367  woman      False  NaN    Cherbourg   yes   True
# 368  woman      False  NaN   Queenstown   yes   True
# 369    NaN        NaN  NaN          NaN   NaN    NaN
#
# [370 rows x 15 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=370, step=1)

# %%
df.shape
# Out:
# (370, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age             76
# sibsp            1
# parch            1
# fare             1
# embarked         2
# class            1
# who              1
# adult_male       1
# deck           286
# embark_town      2
# alive            1
# alone            1
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0    1.0    0.0   71.2833        C   First
# 3           1       1  female  35.0    1.0    0.0   53.1000        S   First
# 6           0       1    male  54.0    0.0    0.0   51.8625        S   First
# 10          1       3  female   4.0    1.0    1.0   16.7000        S   Third
# 11          1       1  female  58.0    0.0    0.0   26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 340         1       2    male   2.0    1.0    1.0   26.0000        S  Second
# 341         1       1  female  24.0    3.0    2.0  263.0000        S   First
# 345         1       2  female  24.0    0.0    0.0   13.0000        S  Second
# 356         1       1  female  22.0    0.0    1.0   55.0000        S   First
# 366         1       1  female  60.0    1.0    0.0   75.2500        C   First
#
#        who adult_male deck  embark_town alive  alone
# 1    woman      False    C    Cherbourg   yes  False
# 3    woman      False    C  Southampton   yes  False
# 6      man       True    E  Southampton    no   True
# 10   child      False    G  Southampton   yes  False
# 11   woman      False    C  Southampton   yes   True
# ..     ...        ...  ...          ...   ...    ...
# 340  child      False    F  Southampton   yes  False
# 341  woman      False    C  Southampton   yes  False
# 345  woman      False    F  Southampton   yes   True
# 356  woman      False    E  Southampton   yes  False
# 366  woman      False    D    Cherbourg   yes  False
#
# [74 rows x 15 columns]

# %%
((784-181)/784)*100
# Out:
# 76.91326530612244

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age             76
# sibsp            1
# parch            1
# fare             1
# embarked         2
# class            1
# who              1
# adult_male       1
# deck           286
# embark_town      2
# alive            1
# alone            1
# dtype: int64

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            76
# sibsp           1
# parch           1
# fare            1
# embarked        2
# class           1
# who             1
# adult_male      1
# embark_town     2
# alive           1
# alone           1
# dtype: int64

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp           float64
# parch           float64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male       object
# embark_town      object
# alive            object
# alone            object
# dtype: object

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df['embark_town'].mode()[0]
# Out:
# 'Southampton'

# %%
df['embark_town'].isnull().sum()
# Out:
# 2

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df['embark_town'].isnull().sum()
# Out:
# 0

# %%
df['age'].isnull().sum()
# Out:
# 76

# %%
df['age'].median()
# Out:
# 28.0

# %%
df['age'].fillna( df['age'].median(), inplace=True)

# %%
df['age'].isnull().sum()
# Out:
# 0

# %%
print('Missing values before imputation -',df['embarked'].isnull().sum())
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
print('Missing values After imputation -',df['embarked'].isnull().sum())
# Out:
# Missing values before imputation - 2
# Missing values After imputation - 0

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  370.000000  370.000000  370.000000  369.000000  369.000000  369.000000
# mean     0.389189    2.332432   28.920946    0.604336    0.384824   32.231198
# std      0.488227    0.826576   12.880914    1.236045    0.786011   49.227708
# min      0.000000    1.000000    0.830000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.925000
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.458300
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   30.695800
# max      1.000000    3.000000   71.000000    8.000000    5.000000  512.329200

# %%
df.describe(include='O')
# Out:
#          sex embarked  who adult_male  embark_town alive alone
# count    370      370  369        369          370   369   369
# unique     3        3    3          2            3     2     2
# top     male        S  man       True  Southampton    no  True
# freq     229      262  210        210          262   226   212

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df['alive']
# Out:
# 0       no
# 1      yes
# 2      yes
# 3      yes
# 4       no
#       ...
# 365     no
# 366    yes
# 367    yes
# 368    yes
# 369    NaN
# Name: alive, Length: 370, dtype: object

# %%
df['embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 365    S
# 366    C
# 367    C
# 368    Q
# 369    S
# Name: embarked, Length: 370, dtype: object

# %%
#df['embarked'].replace({'S':1,'C':2,'Q':3},inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

lb=LabelEncoder()
df['embarked']=lb.fit_transform(df['embarked'])

# %%
df['embarked'].unique()
# Out:
# array([2, 0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     370 non-null    int64
#  1   pclass       370 non-null    int64
#  2   sex          370 non-null    object
#  3   age          370 non-null    float64
#  4   sibsp        369 non-null    float64
#  5   parch        369 non-null    float64
#  6   fare         369 non-null    float64
#  7   embarked     370 non-null    int32
#  8   class        369 non-null    category
#  9   who          369 non-null    object
#  10  adult_male   369 non-null    object
#  11  embark_town  370 non-null    object
#  12  alive        369 non-null    object
#  13  alone        369 non-null    object
# dtypes: category(1), float64(4), int32(1), int64(2), object(6)
# memory usage: 36.8+ KB

# %%
df['sex'].unique()
# Out:
# array(['male', 'female', 'femal'], dtype=object)

# %%
df['sex']=lb.fit_transform(df['sex'])

# %%
df['sex'].unique()
# Out:
# array([2, 1, 0])

# %%
df['class']
# Out:
# 0      2
# 1      0
# 2      2
# 3      0
# 4      2
#       ..
# 365    2
# 366    0
# 367    2
# 368    2
# 369    3
# Name: class, Length: 370, dtype: int32

# %%
df['class'].unique()
# Out:
# ['Third', 'First', 'Second', NaN]
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df['class']=lb.fit_transform(df['class'])

# %%
df['class'].unique()
# Out:
# array([2, 0, 1, 3], dtype=int64)

# %%
df['who']
# Out:
# 0        man
# 1      woman
# 2      woman
# 3      woman
# 4        man
#        ...
# 365      man
# 366    woman
# 367    woman
# 368    woman
# 369      NaN
# Name: who, Length: 370, dtype: object

# %%
df['who'].unique()
# Out:
# array(['man', 'woman', 'child', nan], dtype=object)

# %%
df['who']=lb.fit_transform(df['who'])

# %%
df['who'].unique()
# Out:
# array([1, 2, 0, 3])

# %%
print('Before ',df['embark_town'].unique())
df['who']=lb.fit_transform(df['who'])
print('After ',df['who'].unique())
# Out:
# Before  ['Southampton' 'Cherbourg' 'Queenstown']
# After  [1 2 0 3]

# %%
print('Before ',df['embark_town'].unique())
df['embark_town']=lb.fit_transform(df['embark_town'])
print('After ',df['embark_town'].unique())
# Out:
# Before  ['Southampton' 'Cherbourg' 'Queenstown']
# After  [2 0 1]

# %%
print('Before ',df['alive'].unique())
df['alive']=lb.fit_transform(df['alive'])
print('After ',df['alive'].unique())
# Out:
# Before  ['no' 'yes' nan]
# After  [0 1 2]
